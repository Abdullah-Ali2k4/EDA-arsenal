# %%
import sys
from pathlib import Path
sys.path.append(str(Path("/home/abdullah/Desktop/EDA-arsenal")))
from datasets import Loader

# %%
df=Loader().load_diamondsDataset()
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %% [markdown]
# ## Data Types
#
# ### Numerical
# #### Continuous
# - Age
# - Salary
# - Temperature
#
# #### Discrete
# - Number of siblings
# - Number of cars
#
# ### Categorical
# #### Nominal
# - Gender
# - Country
# - Color
# - Ticket
#
# #### Ordinal
# - Rating
# - Pclass
#
# ### Datetime
# - Date
# - Time
# - Timestamp

# %%
df.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object
